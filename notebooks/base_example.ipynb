# %%
import pandas as pd
import pdpipe as pdp

# %%
df = pd.DataFrame(
    data=[
        [23, 'Jo', 'M', True, 0.07, 'USA', 'Living life to its fullest'],
        [23, 'Dana', 'F', True, 0.3, 'USA', 'the pen is mightier then the sword'],
        [25, 'Bo', 'M', False, 2.3, 'Greece', 'all for one and one for all'],
        [44, 'Derek', 'M', True, 1.1, 'Denmark', 'every life is precious'],
        [72, 'Regina', 'F', True, 7.1, 'Greece', 'all of you get off my porch'],
        [50, 'Jim', 'M', False, 0.2, 'Germany', 'boy do I love dogs and cats'],
        [80, 'Richy', 'M', False, 100.2, 'Finland', 'I gots the dollarz'],
        [80, 'Wealthus', 'F', False, 123.2, 'Finland', 'me likey them moniez'],
    ],
    columns=['Age', 'Name', 'Gender', 'Smoking', 'Savings', 'Country', 'Quote'],
)

# %%
df
# Out:
#    Age      Name Gender  Smoking  Savings  Country  \
# 0   23        Jo      M     True     0.07      USA
# 1   23      Dana      F     True     0.30      USA
# 2   25        Bo      M    False     2.30   Greece
# 3   44     Derek      M     True     1.10  Denmark
# 4   72    Regina      F     True     7.10   Greece
# 5   50       Jim      M    False     0.20  Germany
# 6   80     Richy      M    False   100.20  Finland
# 7   80  Wealthus      F    False   123.20  Finland
#
#                                 Quote
# 0          Living life to its fullest
# 1  the pen is mightier then the sword
# 2         all for one and one for all
# 3              every life is precious
# 4         all of you get off my porch
# 5         boy do I love dogs and cats
# 6                  I gots the dollarz
# 7                me likey them moniez

# %%
pipeline = pdp.ColDrop('Name').RowDrop({'Savings': lambda x: x > 100}).Bin({'Savings': [1]}, drop=False).Scale(
    'StandardScaler').TokenizeText('Quote').SnowballStem('EnglishStemmer', columns=['Quote']).RemoveStopwords(
    'English', 'Quote').Encode('Gender').OneHotEncode('Country')

# %%
pdp.cq.OfDtypes(int).__doc__
# Out:
# "Columns of dtypes <class 'int'>"

# %%
pipeline
# Out:
# A pdpipe pipeline:
# [ 0]  Drop columns Name
# [ 1]  Drop rows in columns Savings by conditions
# [ 2]  Bin Savings by [1].
# [ 3]  Scale columns Columns of dtypes <class 'numpy.number'>
# [ 4]  Tokenize Quote
# [ 5]  Stemming tokens in Quote...
# [ 6]  Remove stopwords from Quote
# [ 7]  Encode Gender
# [ 8]  One-hot encode Country

# %%
print(pipeline[0]._mem_str())
# Out:
#   - _DEF_DESCRIPTION, 66b (137.50%)
#   - _DEF_EXC_MSG, 81b (168.75%)
#   - _INIT_KWARGS, 104b (216.67%)
#   - _abc_impl, 48b (100.00%)
#   - _appmsg, 66b (137.50%)
#   - _col_arg, 64b (133.33%)
#   - _col_str, 53b (110.42%)
#   - _desc, 66b (137.50%)
#   - _errors, 16b (33.33%)
#   - _exclude_columns, 16b (33.33%)
#   - _exmsg, 134b (279.17%)
#   - _exmsg_post, 134b (279.17%)
#   - _exraise, 28b (58.33%)
#   - _name, 49b (102.08%)
#   - _none_cols, 16b (33.33%)
#   - _none_error, 28b (58.33%)
#   - _post_arg, 16b (33.33%)
#   - _prec_arg, 16b (33.33%)
#   - _skip, 16b (33.33%)
#   - application_context, 16b (33.33%)
#   - fit_context, 16b (33.33%)
#   - is_fitted, 24b (50.00%)

# %%
pipeline.memory_report()
# Out:
# === Pipeline memory report ===
# Total pipeline size in memory: 48.00b
# Per-stage memory structure:
# [ 0] 48b (100.00%), Drop columns Name
#   - _DEF_DESCRIPTION, 66b (137.50%)
#   - _DEF_EXC_MSG, 81b (168.75%)
#   - _INIT_KWARGS, 104b (216.67%)
#   - _abc_impl, 48b (100.00%)
#   - _appmsg, 66b (137.50%)
#   - _col_arg, 64b (133.33%)
#   - _col_str, 53b (110.42%)
#   - _desc, 66b (137.50%)
#   - _errors, 16b (33.33%)
#   - _exclude_columns, 16b (33.33%)
#   - _exmsg, 134b (279.17%)
#   - _exmsg_post, 134b (279.17%)
#   - _exraise, 28b (58.33%)
#   - _name, 49b (102.08%)
#   - _none_cols, 16b (33.33%)
#   - _none_error, 28b (58.33%)
#   - _post_arg, 16b (33.33%)
#   - _prec_arg, 16b (33.33%)
#   - _skip, 16b (33.33%)
#   - application_context, 16b (33.33%)
#   - fit_context, 16b (33.33%)
#   - is_fitted, 24b (50.00%)
# [ 1] 48b (100.00%), Drop rows in columns Savings by conditions
#   - _DEF_DESCRIPTION, 66b (137.50%)
#   - _DEF_EXC_MSG, 81b (168.75%)
#   - _INIT_KWARGS, 104b (216.67%)
#   - _REDUCERS, 232b (483.33%)
#   - _abc_impl, 48b (100.00%)
#   - _appmsg, 91b (189.58%)
#   - _col_arg, 64b (133.33%)
#   - _col_str, 56b (116.67%)
#   - _cond_is_dict, 28b (58.33%)
#   - _conditions, 232b (483.33%)
#   - _desc, 91b (189.58%)
#   - _exclude_columns, 16b (33.33%)
#   - _exmsg, 137b (285.42%)
#   - _exmsg_post, 137b (285.42%)
#   - _exraise, 28b (58.33%)
#   - _name, 49b (102.08%)
#   - _none_error, 24b (50.00%)
#   - _post_arg, 16b (33.33%)
#   - _prec_arg, 16b (33.33%)
#   - _reduce, 52b (108.33%)
#   - _skip, 16b (33.33%)
#   - application_context, 16b (33.33%)
#   - fit_context, 16b (33.33%)
#   - is_fitted, 24b (50.00%)
# [ 2] 48b (100.00%), Bin Savings by [1].
#   - _DEF_BIN_EXC_MSG, 123b (256.25%)
#   - _DEF_DESCRIPTION, 66b (137.50%)
#   - _DEF_EXC_MSG, 81b (168.75%)
#   - _INIT_KWARGS, 104b (216.67%)
#   - _abc_impl, 48b (100.00%)
#   - _appmsg, 68b (141.67%)
#   - _bin_map, 232b (483.33%)
#   - _desc, 68b (141.67%)
#   - _drop, 24b (50.00%)
#   - _exmsg, 128b (266.67%)
#   - _exmsg_post, 128b (266.67%)
#   - _exraise, 28b (58.33%)
#   - _name, 49b (102.08%)
#   - _post_arg, 16b (33.33%)
#   - _prec_arg, 16b (33.33%)
#   - _skip, 16b (33.33%)
#   - application_context, 16b (33.33%)
#   - fit_context, 16b (33.33%)
#   - is_fitted, 24b (50.00%)
# [ 3] 48b (100.00%), Scale columns Columns of dtypes <class 'numpy.number'>
#   - _DEF_DESCRIPTION, 66b (137.50%)
#   - _DEF_EXC_MSG, 81b (168.75%)
#   - _INIT_KWARGS, 104b (216.67%)
#   - _abc_impl, 48b (100.00%)
#   - _appmsg, 103b (214.58%)
#   - _col_str, 89b (185.42%)
#   - _desc, 103b (214.58%)
#   - _exclude_columns, 16b (33.33%)
#   - _exmsg, 170b (354.17%)
#   - _exmsg_post, 170b (354.17%)
#   - _exraise, 28b (58.33%)
#   - _kwargs, 64b (133.33%)
#   - _name, 49b (102.08%)
#   - _none_error, 24b (50.00%)
#   - _post_arg, 16b (33.33%)
#   - _prec_arg, 16b (33.33%)
#   - _skip, 16b (33.33%)
#   - application_context, 16b (33.33%)
#   - fit_context, 16b (33.33%)
#   - is_fitted, 24b (50.00%)
#   - joint, 24b (50.00%)
#   - scaler, 63b (131.25%)
# [ 4] 48b (100.00%), Tokenize Quote
#   - _DEF_DESCRIPTION, 66b (137.50%)
#   - _DEF_EXC_MSG, 81b (168.75%)
#   - _DEF_TOKENIZE_APP_MSG, 65b (135.42%)
#   - _DEF_TOKENIZE_EXC_MSG, 153b (318.75%)
#   - _INIT_KWARGS, 104b (216.67%)
#   - _abc_impl, 48b (100.00%)
#   - _appmsg, 63b (131.25%)
#   - _col_arg, 64b (133.33%)
#   - _col_str, 54b (112.50%)
#   - _columns, 64b (133.33%)
#   - _desc, 63b (131.25%)
#   - _drop, 28b (58.33%)
#   - _exclude_columns, 16b (33.33%)
#   - _exmsg, 156b (325.00%)
#   - _exmsg_post, 156b (325.00%)
#   - _exraise, 28b (58.33%)
#   - _name, 49b (102.08%)
#   - _none_cols, 16b (33.33%)
#   - _none_error, 28b (58.33%)
#   - _post_arg, 16b (33.33%)
#   - _prec_arg, 16b (33.33%)
#   - _result_columns, 16b (33.33%)
#   - _skip, 16b (33.33%)
#   - application_context, 16b (33.33%)
#   - fit_context, 16b (33.33%)
#   - is_fitted, 24b (50.00%)
#   - suffix, 53b (110.42%)
# [ 5] 48b (100.00%), Stemming tokens in Quote...
#   - _DEF_DESCRIPTION, 66b (137.50%)
#   - _DEF_EXC_MSG, 81b (168.75%)
#   - _DEF_STEM_DESC, 75b (156.25%)
#   - _DEF_STEM_EXC_MSG, 157b (327.08%)
#   - _INIT_KWARGS, 104b (216.67%)
#   - _abc_impl, 48b (100.00%)
#   - _appmsg, 76b (158.33%)
#   - _col_arg, 64b (133.33%)
#   - _col_str, 54b (112.50%)
#   - _columns, 64b (133.33%)
#   - _desc, 76b (158.33%)
#   - _drop, 28b (58.33%)
#   - _exclude_columns, 16b (33.33%)
#   - _exmsg, 160b (333.33%)
#   - _exmsg_post, 160b (333.33%)
#   - _exraise, 28b (58.33%)
#   - _name, 49b (102.08%)
#   - _none_cols, 16b (33.33%)
#   - _none_error, 28b (58.33%)
#   - _post_arg, 16b (33.33%)
#   - _prec_arg, 16b (33.33%)
#   - _result_columns, 16b (33.33%)
#   - _skip, 16b (33.33%)
#   - application_context, 16b (33.33%)
#   - fit_context, 16b (33.33%)
#   - is_fitted, 24b (50.00%)
#   - stemmer, 48b (100.00%)
#   - stemmer_name, 63b (131.25%)
#   - suffix, 54b (112.50%)
# [ 6] 48b (100.00%), Remove stopwords from Quote
#   - _DEF_DESCRIPTION, 66b (137.50%)
#   - _DEF_EXC_MSG, 81b (168.75%)
#   - _DEF_STOPWORDS_APP_MSG, 78b (162.50%)
#   - _DEF_STOPWORDS_EXC_MSG, 160b (333.33%)
#   - _INIT_KWARGS, 104b (216.67%)
#   - _abc_impl, 48b (100.00%)
#   - _appmsg, 76b (158.33%)
#   - _col_arg, 64b (133.33%)
#   - _col_str, 54b (112.50%)
#   - _columns, 64b (133.33%)
#   - _desc, 76b (158.33%)
#   - _drop, 28b (58.33%)
#   - _exclude_columns, 16b (33.33%)
#   - _exmsg, 163b (339.58%)
#   - _exmsg_post, 163b (339.58%)
#   - _exraise, 28b (58.33%)
#   - _language, 56b (116.67%)
#   - _name, 49b (102.08%)
#   - _none_cols, 16b (33.33%)
#   - _none_error, 28b (58.33%)
#   - _post_arg, 16b (33.33%)
#   - _prec_arg, 16b (33.33%)
#   - _result_columns, 16b (33.33%)
#   - _skip, 16b (33.33%)
#   - _stopwords_list, 1.66Kb (3466.67%)
#   - application_context, 16b (33.33%)
#   - fit_context, 16b (33.33%)
#   - is_fitted, 24b (50.00%)
#   - suffix, 56b (116.67%)
# [ 7] 48b (100.00%), Encode Gender
#   - _DEF_DESCRIPTION, 66b (137.50%)
#   - _DEF_EXC_MSG, 81b (168.75%)
#   - _INIT_KWARGS, 104b (216.67%)
#   - _abc_impl, 48b (100.00%)
#   - _appmsg, 62b (129.17%)
#   - _col_arg, 64b (133.33%)
#   - _col_str, 55b (114.58%)
#   - _desc, 62b (129.17%)
#   - _drop, 28b (58.33%)
#   - _exclude_columns, 16b (33.33%)
#   - _exmsg, 136b (283.33%)
#   - _exmsg_post, 136b (283.33%)
#   - _exraise, 28b (58.33%)
#   - _name, 49b (102.08%)
#   - _none_error, 24b (50.00%)
#   - _post_arg, 16b (33.33%)
#   - _prec_arg, 16b (33.33%)
#   - _skip, 16b (33.33%)
#   - application_context, 16b (33.33%)
#   - encoders, 64b (133.33%)
#   - fit_context, 16b (33.33%)
#   - is_fitted, 24b (50.00%)
# [ 8] 48b (100.00%), One-hot encode Country
#   - _DEF_DESCRIPTION, 66b (137.50%)
#   - _DEF_EXC_MSG, 81b (168.75%)
#   - _INIT_KWARGS, 104b (216.67%)
#   - _abc_impl, 48b (100.00%)
#   - _appmsg, 71b (147.92%)
#   - _col_arg, 64b (133.33%)
#   - _col_str, 56b (116.67%)
#   - _desc, 71b (147.92%)
#   - _drop, 28b (58.33%)
#   - _drop_first, 28b (58.33%)
#   - _dummy_col_map, 64b (133.33%)
#   - _dummy_na, 24b (50.00%)
#   - _encoder_map, 64b (133.33%)
#   - _exclude_columns, 16b (33.33%)
#   - _exmsg, 137b (285.42%)
#   - _exmsg_post, 137b (285.42%)
#   - _exraise, 28b (58.33%)
#   - _name, 49b (102.08%)
#   - _none_error, 24b (50.00%)
#   - _post_arg, 16b (33.33%)
#   - _prec_arg, 16b (33.33%)
#   - _skip, 16b (33.33%)
#   - application_context, 16b (33.33%)
#   - fit_context, 16b (33.33%)
#   - is_fitted, 24b (50.00%)

# %%
pipeline(df, verbose=True)
# Out:
# - Drop columns Name
# - Drop rows in columns Savings by conditions
# 2 rows dropped.
# - Bin Savings by [1].
# Savings: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 179.92it/s]
# - Scale columns Columns of dtypes <class 'numpy.number'>
# - Tokenize Quote
# - Stemming tokens in Quote...
# - Remove stopwords from Quote
# - Encode Gender
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 273.39it/s]
# - One-hot encode Country
# Country: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 226.54it/s]
#         Age  Gender  Smoking   Savings Savings_bin                    Quote  \
# 0 -0.917257       1     True -0.718473          <1    [live, life, fullest]
# 1 -0.917257       0     True -0.625375          <1   [pen, mightier, sword]
# 2 -0.806074       1    False  0.184172          1≤               [one, one]
# 3  0.250161       1     True -0.301556          1≤  [everi, life, precious]
# 4  1.806718       0     True  2.127084          1≤             [get, porch]
# 5  0.583709       1    False -0.665852          <1    [boy, love, dog, cat]
#
#    Country_Germany  Country_Greece  Country_USA
# 0                0               0            1
# 1                0               0            1
# 2                0               1            0
# 3                0               0            0
# 4                0               1            0
# 5                1               0            0

# %%
pipeline[2:4](df, verbose=True)
# Out:
# - Bin Savings by [1].
# Savings: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 304.97it/s]
# - Scale columns Columns of dtypes <class 'numpy.number'>
#         Age      Name Gender  Smoking   Savings Savings_bin  Country  \
# 0 -1.135052        Jo      M     True -0.609615          <1      USA
# 1 -1.135052      Dana      F     True -0.604820          <1      USA
# 2 -1.049790        Bo      M    False -0.563121          1≤   Greece
# 3 -0.239800     Derek      M     True -0.588140          1≤  Denmark
# 4  0.953870    Regina      F     True -0.463043          1≤   Greece
# 5  0.015987       Jim      M    False -0.606905          <1  Germany
# 6  1.294918     Richy      M    False  1.478052          1≤  Finland
# 7  1.294918  Wealthus      F    False  1.957592          1≤  Finland
#
#                                 Quote
# 0          Living life to its fullest
# 1  the pen is mightier then the sword
# 2         all for one and one for all
# 3              every life is precious
# 4         all of you get off my porch
# 5         boy do I love dogs and cats
# 6                  I gots the dollarz
# 7                me likey them moniez

# %%
pl = pdp.ColDrop('Name').RowDrop({'Savings': lambda x: x > 100}).Bin({'Savings': [1]}, drop=False).Scale(
    'StandardScaler').TokenizeText('Quote').SnowballStem('EnglishStemmer', columns=['Quote']).RemoveStopwords(
    'English', 'Quote').Encode('Gender').OneHotEncode('Country')

# %%
pl(df)
# Out:
#         Age  Gender  Smoking   Savings Savings_bin                    Quote  \
# 0 -0.917257       1     True -0.718473          <1    [live, life, fullest]
# 1 -0.917257       0     True -0.625375          <1   [pen, mightier, sword]
# 2 -0.806074       1    False  0.184172          1≤               [one, one]
# 3  0.250161       1     True -0.301556          1≤  [everi, life, precious]
# 4  1.806718       0     True  2.127084          1≤             [get, porch]
# 5  0.583709       1    False -0.665852          <1    [boy, love, dog, cat]
#
#    Country_Germany  Country_Greece  Country_USA
# 0                0               0            1
# 1                0               0            1
# 2                0               1            0
# 3                0               0            0
# 4                0               1            0
# 5                1               0            0
