# %%
import pandas as pd
import pdpipe as pdp

# %%
df = pd.DataFrame(
    data=[
        [23, 'Jo', 'M', True, 0.07, 'USA', 'Living life to its fullest'],
        [23, 'Dana', 'F', True, 0.3, 'USA', 'the pen is mightier then the sword'],
        [25, 'Bo', 'M', False, 2.3, 'Greece', 'all for one and one for all'],
        [44, 'Derek', 'M', True, 1.1, 'Denmark', 'every life is precious'],
        [72, 'Regina', 'F', True, 7.1, 'Greece', 'all of you get off my porch'],
        [50, 'Jim', 'M', False, 0.2, 'Germany', 'boy do I love dogs and cats'],
        [80, 'Richy', 'M', False, 100.2, 'Finland', 'I gots the dollarz'],
        [80, 'Wealthus', 'F', False, 123.2, 'Finland', 'me likey them moniez'],
    ],
    columns=['Age', 'Name', 'Gender', 'Smoking', 'Savings', 'Country', 'Quote'],
)

# %%
df
# Out:
#    Age    Name Gender  Smoking  Savings  Country  \
# 0   23      Jo      M     True     0.07      USA
# 1   23    Dana      F     True     0.30      USA
# 2   25      Bo      M    False     2.30   Greece
# 3   44   Derek      M     True     1.10  Denmark
# 4   72  Regina      F     True     7.10   Greece
# 5   50     Jim      M    False     0.20  Germany
#
#                                 Quote
# 0          Living life to its fullest
# 1  the pen is mightier then the sword
# 2         all for one and one for all
# 3              every life is precious
# 4         all of you get off my porch
# 5         boy do I love dogs and cats

# %%
pipeline = pdp.ColDrop('Name').RowDrop({'Savings': lambda x: x > 100}).Bin({'Savings': [1]}, drop=False).Scale(
    'StandardScaler').TokenizeWords('Quote').SnowballStem('EnglishStemmer', columns=['Quote']).RemoveStopwords(
    'English', 'Quote').Encode('Gender').OneHotEncode('Country')

# %%
pipeline
# Out:
# A pdpipe pipeline:
# [ 0]  Drop column Name
# [ 1]  Drop rows by conditions: {'Savings': <function <lambda> at
#       0x12794de60>}
# [ 2]  Bin Savings by [1].
# [ 3]  Scale data.
# [ 4]  Tokenize Quote
# [ 5]  Stem tokens in Quote
# [ 6]  Removing stopwords from Quote
# [ 7]  Encode Gender
# [ 8]  One-hot encode Country

# %%
pipeline(df, verbose=True)
# Out:
# - Dropping columns Name...
# - Dropping rows by conditions: Savings...
# 2 rows dropped.
# - Binning column Savings...
# Savings: 100%|██████████| 1/1 [00:00<00:00, 164.05it/s]
# - Scaling data...
# - Tokenizing Quote...
# - Stemming tokens in Quote...
# - Removing stopwords from Quote...
# - Encoding Gender...
# 100%|██████████| 1/1 [00:00<00:00, 108.87it/s]
# - One-hot encoding Country...
# Country: 100%|██████████| 1/1 [00:00<00:00, 134.19it/s]
#         Age  Gender   Smoking   Savings Savings_bin                    Quote  \
# 0 -0.917257       1  0.707107 -0.718473          <1    [live, life, fullest]
# 1 -0.917257       0  0.707107 -0.625375          <1   [pen, mightier, sword]
# 2 -0.806074       1 -1.414214  0.184172          1≤               [one, one]
# 3  0.250161       1  0.707107 -0.301556          1≤  [everi, life, precious]
# 4  1.806718       0  0.707107  2.127084          1≤             [get, porch]
# 5  0.583709       1 -1.414214 -0.665852          <1    [boy, love, dog, cat]
#
#    Country_Germany  Country_Greece  Country_USA
# 0                0               0            1
# 1                0               0            1
# 2                0               1            0
# 3                0               0            0
# 4                0               1            0
# 5                1               0            0

# %%
pipeline[2:4](df, verbose=True)
# Out:
# - Binning column Savings...
# Savings: 100%|██████████| 1/1 [00:00<00:00, 153.37it/s]
# - Scaling data...
#         Age      Name Gender   Smoking    Savings Savings_bin  Country  \
# 0 -0.917257        Jo      M  0.707107  -0.718473          <1      USA
# 1 -0.917257      Dana      F  0.707107  -0.625375          <1      USA
# 2 -0.806074        Bo      M -1.414214   0.184172          1≤   Greece
# 3  0.250161     Derek      M  0.707107  -0.301556          1≤  Denmark
# 4  1.806718    Regina      F  0.707107   2.127084          1≤   Greece
# 5  0.583709       Jim      M -1.414214  -0.665852          <1  Germany
# 6  2.251448     Richy      M -1.414214  39.811492          1≤  Finland
# 7  2.251448  Wealthus      F -1.414214  49.121281          1≤  Finland
#
#                                 Quote
# 0          Living life to its fullest
# 1  the pen is mightier then the sword
# 2         all for one and one for all
# 3              every life is precious
# 4         all of you get off my porch
# 5         boy do I love dogs and cats
# 6                  I gots the dollarz
# 7                me likey them moniez
