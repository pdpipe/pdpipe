# %%
import re, sys, inspect, subprocess

# %%
import pdpipe

# %%
from numpydoc.validate import ERROR_MSGS, validate

# %%
module_blacklist = ['_version', 'cfg']

# %%
HIDE_ERROR_CODES_LIST = [
    'ES01',  # No extended summary found
    'SA01',  # See Also section not found
    'EX01',  # No examples section found
]

# %%
HIDE_ERROR_REGEX = '|'.join([
    ':{}:'.format(code)
    for code in HIDE_ERROR_CODES_LIST
])

# %%
HIDE_ERROR_PATTERN = re.compile(HIDE_ERROR_REGEX)

# %%
SOFT_ERROR_CODES_LIST = HIDE_ERROR_CODES_LIST + [
    'GL01',  # Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
]

# %%
SOFT_ERROR_REGEX = '|'.join([
    ':{}:'.format(code)
    for code in SOFT_ERROR_CODES_LIST
])

# %%
SOFT_ERROR_PATTERN = re.compile(SOFT_ERROR_REGEX)

# %%
def get_npdoc_val_report(object_name) -> bool:
    """Prints a numpydoc validation report of the Python object of the given name.
    
    Parameters
    ----------
    object_name : str
        The name of the object for which to run numpydoc docstring validation.
        
    Returns
    -------
    bool
        True if any hard errors were found (errors not defined as soft errors
        in the SOFT_ERROR_CODES_LIST).
    """
    any_errors = False
    any_hard_errors = False
    print(f"\nnumpydoc validation results for {object_name}:")
    try:
        output = subprocess.check_output(['python', '-m', 'numpydoc', object_name, '--validate'])
    except subprocess.CalledProcessError as e:
        any_errors = True
        output = e.output
    decoded_output = output.decode("utf-8")
    # if output includes ANY hard error code
    # calc by comparing N of soft errors w/ N lines
    report_lines = decoded_output.split('\n')
    nlines = len(report_lines) - 1
    nsoft = len(SOFT_ERROR_PATTERN.findall(decoded_output))
    nhide = len(HIDE_ERROR_PATTERN.findall(decoded_output))
    nerrors = nlines - nhide
    if nlines > nsoft:
        any_hard_errors = True
    if nerrors > 0:
        print(f"A total of {nerrors} errors were found")
        print(
            f"Out of which {nsoft-nhide} are soft errors"
            f", (an additional {nhide} errors were hidden)."
        )
        for line in report_lines:
            if len(HIDE_ERROR_PATTERN.findall(line)) < 1 and len(line) >0:
                print(line)
    else:
        print("No errors found.")
    return any_hard_errors

# %%
get_npdoc_val_report('pdpipe')
# Out:
# numpydoc validation results for pdpipe:
# No errors found.
# False

# %%
def recursively_validate_object(val_obj, val_full_name) -> bool:
    obj_w_hard_errors = []
    if get_npdoc_val_report(val_full_name):
        obj_w_hard_errors = [val_full_name]
    for name, obj in inspect.getmembers(val_obj):
        if not name.startswith('_'):
            if inspect.isclass(obj) or inspect.isfunction(obj):
                full_name = f"{val_full_name}.{name}"
                res = recursively_validate_object(obj, full_name)
                if len(res) > 0:
                    obj_w_hard_errors.extend(res)
    return sorted(set(obj_w_hard_errors))

# %%
def validate_module(module_name):
    print(f"Validating numpy docstrings in the {module_name} module!")
    obj_w_hard_errors = []
    res = get_npdoc_val_report(module_name)
    if res:
        obj_w_hard_errors.append(module_name)
    for name, obj in inspect.getmembers(sys.modules[module_name]):
        # print(obj)
        # if inspect.isclass(obj):
        #     print(obj)
        if inspect.ismodule(obj) and name not in module_blacklist:
            module_full_name = f"{module_name}.{name}"
            # print(f"Found pdpipe sub-module {module_full_name}")
            res = recursively_validate_object(obj, module_full_name)
            obj_w_hard_errors.extend(res)
    obj_w_hard_errors = sorted(set(obj_w_hard_errors))
    if len(obj_w_hard_errors) > 0:
        print("Hard errors were found in the following objects:")
        print('\n'.join(obj_w_hard_errors))
        # print(obj_w_hard_errors)
    else:
        print("No hard errors were found anywhere in the module!")

# %%
validate_module('pdpipe')
# Out:
# Validating numpy docstrings in the pdpipe module!
#
# numpydoc validation results for pdpipe:
# No errors found.
#
# numpydoc validation results for pdpipe.cfg:
# No errors found.
#
# numpydoc validation results for pdpipe.cfg.CfgKey:
# A total of 1 errors were found
# Out of which 0 are soft errors, (an additional 0 errors were hidden).
# pdpipe.cfg.CfgKey:GL08:The object does not have a docstring
#
# numpydoc validation results for pdpipe.cond:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.AlwaysTrue:
# A total of 1 errors were found
# Out of which 0 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cond.AlwaysTrue:PR01:Parameters {'**kwargs'} not documented
#
# numpydoc validation results for pdpipe.cond.AlwaysTrue.fit:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cond.AlwaysTrue.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cond.AlwaysTrue.fit_transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.AlwaysTrue.transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.ColumnsFromList:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.ColumnsFromList.fit:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cond.ColumnsFromList.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cond.ColumnsFromList.fit_transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.ColumnsFromList.transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.Condition:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.Condition.fit:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cond.Condition.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cond.Condition.fit_transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.Condition.transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasAllColumns:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasAllColumns.fit:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cond.HasAllColumns.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cond.HasAllColumns.fit_transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasAllColumns.transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasAtLeastNQualifyingColumns:
# A total of 1 errors were found
# Out of which 0 are soft errors, (an additional 1 errors were hidden).
# pdpipe.cond.HasAtLeastNQualifyingColumns:SS06:Summary should fit in a single line
#
# numpydoc validation results for pdpipe.cond.HasAtLeastNQualifyingColumns.fit:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cond.HasAtLeastNQualifyingColumns.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cond.HasAtLeastNQualifyingColumns.fit_transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasAtLeastNQualifyingColumns.transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasAtMostMissingValues:
# A total of 1 errors were found
# Out of which 0 are soft errors, (an additional 1 errors were hidden).
# pdpipe.cond.HasAtMostMissingValues:SS06:Summary should fit in a single line
#
# numpydoc validation results for pdpipe.cond.HasAtMostMissingValues.fit:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cond.HasAtMostMissingValues.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cond.HasAtMostMissingValues.fit_transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasAtMostMissingValues.transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasAtMostNQualifyingColumns:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasAtMostNQualifyingColumns.fit:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cond.HasAtMostNQualifyingColumns.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cond.HasAtMostNQualifyingColumns.fit_transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasAtMostNQualifyingColumns.transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasNoColumn:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasNoColumn.fit:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cond.HasNoColumn.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cond.HasNoColumn.fit_transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasNoColumn.transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasNoMissingValues:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasNoMissingValues.fit:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cond.HasNoMissingValues.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cond.HasNoMissingValues.fit_transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasNoMissingValues.transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasNoQualifyingColumns:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasNoQualifyingColumns.fit:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cond.HasNoQualifyingColumns.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cond.HasNoQualifyingColumns.fit_transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.HasNoQualifyingColumns.transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.PerColumnCondition:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.PerColumnCondition.fit:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cond.PerColumnCondition.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cond.PerColumnCondition.fit_transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.PerColumnCondition.transform:
# No errors found.
#
# numpydoc validation results for pdpipe.cond.UnfittedConditionError:
# A total of 1 errors were found
# Out of which 0 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cond.UnfittedConditionError:SS06:Summary should fit in a single line
#
# numpydoc validation results for pdpipe.cq:
# No errors found.
#
# numpydoc validation results for pdpipe.cq.AllColumns:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.AllColumns:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.AllColumns.fit:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.AllColumns.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.AllColumns.fit:GL02:Closing quotes should be placed in the line after the last text in the docstring (do not close the quotes in the same line as the text, or leave a blank line between the last text and the quotes)
# pdpipe.cq.AllColumns.fit:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.cq.AllColumns.fit:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.AllColumns.fit_transform:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.AllColumns.fit_transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.AllColumns.transform:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.AllColumns.transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.AllColumns.transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.ByColumnCondition:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.ByColumnCondition:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.ByColumnCondition.fit:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.ByColumnCondition.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.ByColumnCondition.fit:GL02:Closing quotes should be placed in the line after the last text in the docstring (do not close the quotes in the same line as the text, or leave a blank line between the last text and the quotes)
# pdpipe.cq.ByColumnCondition.fit:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.cq.ByColumnCondition.fit:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.ByColumnCondition.fit_transform:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.ByColumnCondition.fit_transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.ByColumnCondition.transform:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.ByColumnCondition.transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.ByColumnCondition.transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.ByLabels:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.ByLabels:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.ByLabels.fit:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.ByLabels.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.ByLabels.fit:GL02:Closing quotes should be placed in the line after the last text in the docstring (do not close the quotes in the same line as the text, or leave a blank line between the last text and the quotes)
# pdpipe.cq.ByLabels.fit:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.cq.ByLabels.fit:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.ByLabels.fit_transform:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.ByLabels.fit_transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.ByLabels.transform:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.ByLabels.transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.ByLabels.transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.ColumnQualifier:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.ColumnQualifier:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.ColumnQualifier.fit:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.ColumnQualifier.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.ColumnQualifier.fit:GL02:Closing quotes should be placed in the line after the last text in the docstring (do not close the quotes in the same line as the text, or leave a blank line between the last text and the quotes)
# pdpipe.cq.ColumnQualifier.fit:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.cq.ColumnQualifier.fit:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.ColumnQualifier.fit_transform:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.ColumnQualifier.fit_transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.ColumnQualifier.transform:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.ColumnQualifier.transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.ColumnQualifier.transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.OfDtypes:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.cq.OfDtypes:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.OfDtypes.fit:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.OfDtypes.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.OfDtypes.fit:GL02:Closing quotes should be placed in the line after the last text in the docstring (do not close the quotes in the same line as the text, or leave a blank line between the last text and the quotes)
# pdpipe.cq.OfDtypes.fit:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.cq.OfDtypes.fit:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.OfDtypes.fit_transform:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.OfDtypes.fit_transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.OfDtypes.transform:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.OfDtypes.transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.OfDtypes.transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.OfNumericDtypes:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.OfNumericDtypes:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.OfNumericDtypes.fit:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.OfNumericDtypes.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.OfNumericDtypes.fit:GL02:Closing quotes should be placed in the line after the last text in the docstring (do not close the quotes in the same line as the text, or leave a blank line between the last text and the quotes)
# pdpipe.cq.OfNumericDtypes.fit:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.cq.OfNumericDtypes.fit:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.OfNumericDtypes.fit_transform:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.OfNumericDtypes.fit_transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.OfNumericDtypes.transform:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.OfNumericDtypes.transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.OfNumericDtypes.transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.StartsWith:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.StartsWith:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.StartsWith.fit:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.StartsWith.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.StartsWith.fit:GL02:Closing quotes should be placed in the line after the last text in the docstring (do not close the quotes in the same line as the text, or leave a blank line between the last text and the quotes)
# pdpipe.cq.StartsWith.fit:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.cq.StartsWith.fit:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.StartsWith.fit_transform:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.StartsWith.fit_transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.StartsWith.transform:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.StartsWith.transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.StartsWith.transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.UnfittedColumnQualifierError:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.UnfittedColumnQualifierError:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.UnfittedColumnQualifierError:SS06:Summary should fit in a single line
#
# numpydoc validation results for pdpipe.cq.WithAtLeastMissingValueRate:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.WithAtLeastMissingValueRate:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.WithAtLeastMissingValueRate.fit:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.WithAtLeastMissingValueRate.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.WithAtLeastMissingValueRate.fit:GL02:Closing quotes should be placed in the line after the last text in the docstring (do not close the quotes in the same line as the text, or leave a blank line between the last text and the quotes)
# pdpipe.cq.WithAtLeastMissingValueRate.fit:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.cq.WithAtLeastMissingValueRate.fit:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.WithAtLeastMissingValueRate.fit_transform:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.WithAtLeastMissingValueRate.fit_transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.WithAtLeastMissingValueRate.transform:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.WithAtLeastMissingValueRate.transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.WithAtLeastMissingValueRate.transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.WithAtMostMissingValueRate:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.WithAtMostMissingValueRate:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.WithAtMostMissingValueRate.fit:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.WithAtMostMissingValueRate.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.WithAtMostMissingValueRate.fit:GL02:Closing quotes should be placed in the line after the last text in the docstring (do not close the quotes in the same line as the text, or leave a blank line between the last text and the quotes)
# pdpipe.cq.WithAtMostMissingValueRate.fit:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.cq.WithAtMostMissingValueRate.fit:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.WithAtMostMissingValueRate.fit_transform:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.WithAtMostMissingValueRate.fit_transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.WithAtMostMissingValueRate.transform:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.WithAtMostMissingValueRate.transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.WithAtMostMissingValueRate.transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.WithAtMostMissingValues:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.WithAtMostMissingValues:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.WithAtMostMissingValues.fit:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.WithAtMostMissingValues.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.WithAtMostMissingValues.fit:GL02:Closing quotes should be placed in the line after the last text in the docstring (do not close the quotes in the same line as the text, or leave a blank line between the last text and the quotes)
# pdpipe.cq.WithAtMostMissingValues.fit:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.cq.WithAtMostMissingValues.fit:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.WithAtMostMissingValues.fit_transform:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.WithAtMostMissingValues.fit_transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.WithAtMostMissingValues.transform:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.WithAtMostMissingValues.transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.WithAtMostMissingValues.transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.WithoutMissingValues:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.WithoutMissingValues:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.WithoutMissingValues.fit:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.WithoutMissingValues.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.WithoutMissingValues.fit:GL02:Closing quotes should be placed in the line after the last text in the docstring (do not close the quotes in the same line as the text, or leave a blank line between the last text and the quotes)
# pdpipe.cq.WithoutMissingValues.fit:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.cq.WithoutMissingValues.fit:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.WithoutMissingValues.fit_transform:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.WithoutMissingValues.fit_transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.cq.WithoutMissingValues.transform:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.WithoutMissingValues.transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.WithoutMissingValues.transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.cq.columns_to_qualifier:
# A total of 3 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.cq.columns_to_qualifier:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.columns_to_qualifier:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.cq.columns_to_qualifier:RT02:The first line of the Returns section should contain only the type, unless multiple values are being returned
#
# numpydoc validation results for pdpipe.cq.is_fittable_column_qualifier:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.cq.is_fittable_column_qualifier:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.cq.is_fittable_column_qualifier:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.exceptions:
# No errors found.
#
# numpydoc validation results for pdpipe.exceptions.FailedConditionError:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.exceptions.FailedConditionError:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.exceptions.FailedConditionError:SS06:Summary should fit in a single line
#
# numpydoc validation results for pdpipe.exceptions.FailedPostconditionError:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.exceptions.FailedPostconditionError:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.exceptions.FailedPostconditionError:SS06:Summary should fit in a single line
#
# numpydoc validation results for pdpipe.exceptions.FailedPreconditionError:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.exceptions.FailedPreconditionError:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.exceptions.FailedPreconditionError:SS06:Summary should fit in a single line
#
# numpydoc validation results for pdpipe.exceptions.PipelineApplicationError:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.exceptions.PipelineApplicationError:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.exceptions.PipelineApplicationError:SS06:Summary should fit in a single line
#
# numpydoc validation results for pdpipe.exceptions.PipelineInitializationError:
# No errors found.
#
# numpydoc validation results for pdpipe.exceptions.UnexpectedPipelineMethodCallError:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.exceptions.UnexpectedPipelineMethodCallError:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.exceptions.UnexpectedPipelineMethodCallError:SS06:Summary should fit in a single line
#
# numpydoc validation results for pdpipe.exceptions.UnfittedPipelineStageError:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.exceptions.UnfittedPipelineStageError:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.exceptions.UnfittedPipelineStageError:SS06:Summary should fit in a single line
#
# numpydoc validation results for pdpipe.fly:
# A total of 1 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.fly:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.fly.DropRowsByQualifier:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier:PR01:Parameters {'**kwargs'} not documented
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier.AdHocStage:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.fly.DropRowsByQualifier.AdHocStage:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier.AdHocStage:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.fly.DropRowsByQualifier.AdHocStage:PR01:Parameters {'**kwargs'} not documented
# pdpipe.fly.DropRowsByQualifier.AdHocStage:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier.AggByCols:
# A total of 6 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.fly.DropRowsByQualifier.AggByCols:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier.AggByCols:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.fly.DropRowsByQualifier.AggByCols:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.fly.DropRowsByQualifier.AggByCols:SS06:Summary should fit in a single line
# pdpipe.fly.DropRowsByQualifier.AggByCols:PR01:Parameters {'**kwargs'} not documented
# pdpipe.fly.DropRowsByQualifier.AggByCols:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier.ApplicationContextEnricher:
# A total of 3 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.fly.DropRowsByQualifier.ApplicationContextEnricher:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier.ApplicationContextEnricher:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.fly.DropRowsByQualifier.ApplicationContextEnricher:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier.ApplyByCols:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.fly.DropRowsByQualifier.ApplyByCols:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier.ApplyByCols:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.fly.DropRowsByQualifier.ApplyByCols:SS06:Summary should fit in a single line
# pdpipe.fly.DropRowsByQualifier.ApplyByCols:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier.ApplyToRows:
# A total of 5 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.fly.DropRowsByQualifier.ApplyToRows:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier.ApplyToRows:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.fly.DropRowsByQualifier.ApplyToRows:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.fly.DropRowsByQualifier.ApplyToRows:PR01:Parameters {'**kwargs'} not documented
# pdpipe.fly.DropRowsByQualifier.ApplyToRows:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier.Bin:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.fly.DropRowsByQualifier.Bin:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier.Bin:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.fly.DropRowsByQualifier.Bin:PR01:Parameters {'**kwargs'} not documented
# pdpipe.fly.DropRowsByQualifier.Bin:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier.ColByFrameFunc:
# A total of 5 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.fly.DropRowsByQualifier.ColByFrameFunc:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier.ColByFrameFunc:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.fly.DropRowsByQualifier.ColByFrameFunc:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.fly.DropRowsByQualifier.ColByFrameFunc:PR01:Parameters {'**kwargs'} not documented
# pdpipe.fly.DropRowsByQualifier.ColByFrameFunc:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier.ColDrop:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.fly.DropRowsByQualifier.ColDrop:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier.ColDrop:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.fly.DropRowsByQualifier.ColDrop:PR01:Parameters {'**kwargs'} not documented
# pdpipe.fly.DropRowsByQualifier.ColDrop:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier.ColRename:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.fly.DropRowsByQualifier.ColRename:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier.ColRename:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.fly.DropRowsByQualifier.ColRename:PR01:Parameters {'**kwargs'} not documented
# pdpipe.fly.DropRowsByQualifier.ColRename:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier.ColReorder:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.fly.DropRowsByQualifier.ColReorder:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier.ColReorder:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.fly.DropRowsByQualifier.ColReorder:PR01:Parameters {'**kwargs'} not documented
# pdpipe.fly.DropRowsByQualifier.ColReorder:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier.ColumnDtypeEnforcer:
# A total of 9 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.fly.DropRowsByQualifier.ColumnDtypeEnforcer:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier.ColumnDtypeEnforcer:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.fly.DropRowsByQualifier.ColumnDtypeEnforcer:PR01:Parameters {'**kwargs', 'errors', 'column_to_dtype'} not documented
# pdpipe.fly.DropRowsByQualifier.ColumnDtypeEnforcer:PR02:Unknown parameters {'errors: {‘raise’', 'column_to_dtype: dict of labels / ColumnQualifiers to dtypes', '‘ignore’}', 'default ‘raise’'}
# pdpipe.fly.DropRowsByQualifier.ColumnDtypeEnforcer:PR10:Parameter "column_to_dtype" requires a space before the colon separating the parameter name and type
# pdpipe.fly.DropRowsByQualifier.ColumnDtypeEnforcer:PR10:Parameter "errors" requires a space before the colon separating the parameter name and type
# pdpipe.fly.DropRowsByQualifier.ColumnDtypeEnforcer:PR04:Parameter "‘ignore’}" has no type
# pdpipe.fly.DropRowsByQualifier.ColumnDtypeEnforcer:PR04:Parameter "default ‘raise’" has no type
# pdpipe.fly.DropRowsByQualifier.ColumnDtypeEnforcer:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier.ColumnTransformer:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.fly.DropRowsByQualifier.ColumnTransformer:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier.ColumnTransformer:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.fly.DropRowsByQualifier.ColumnTransformer:PR01:Parameters {'**kwargs'} not documented
# pdpipe.fly.DropRowsByQualifier.ColumnTransformer:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier.ColumnsBasedPipelineStage:
# /Users/shaypalachy/.pyenv/versions/py3/lib/python3.10/site-packages/numpydoc/docscrape.py:449: UserWarning: potentially wrong underline length...
# Parameters
# --------- in
# Creates and adds a pipeline stage that operates on a subset of dataframe columns to this pipeline stage.
# ... in the docstring of ColumnsBasedPipelineStage in /Users/shaypalachy/clones/pdpipe/pdpipe/core.py.
#   warn(msg)
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.fly.DropRowsByQualifier.ColumnsBasedPipelineStage:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier.ColumnsBasedPipelineStage:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.fly.DropRowsByQualifier.ColumnsBasedPipelineStage:PR01:Parameters {'desc_temp', '**kwargs', 'columns', 'exclude_columns', 'none_columns'} not documented
# pdpipe.fly.DropRowsByQualifier.ColumnsBasedPipelineStage:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.fly.DropRowsByQualifier.ConditionValidator:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.fly.DropRowsByQualifier.ConditionValidator:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.fly.DropRowsByQualifier.ConditionValidator:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.fly.DropRowsByQualifier.ConditionValidator:PR01:Parameters {'**kwargs'} not documented
# ...
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.nltk_stages.RemoveStopwords.SetIndex:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.RemoveStopwords.SetIndex:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.RemoveStopwords.SetIndex:PR01:Parameters {'**kwargs', 'keys'} not documented
# pdpipe.nltk_stages.RemoveStopwords.SetIndex:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.RemoveStopwords.SnowballStem:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.nltk_stages.RemoveStopwords.SnowballStem:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.RemoveStopwords.SnowballStem:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.RemoveStopwords.SnowballStem:PR01:Parameters {'**kwargs'} not documented
# pdpipe.nltk_stages.RemoveStopwords.SnowballStem:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.RemoveStopwords.TfidfVectorizeTokenLists:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.nltk_stages.RemoveStopwords.TfidfVectorizeTokenLists:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.RemoveStopwords.TfidfVectorizeTokenLists:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.RemoveStopwords.TfidfVectorizeTokenLists:PR01:Parameters {'**kwargs'} not documented
# pdpipe.nltk_stages.RemoveStopwords.TfidfVectorizeTokenLists:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.RemoveStopwords.TokenizeText:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.nltk_stages.RemoveStopwords.TokenizeText:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.RemoveStopwords.TokenizeText:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.RemoveStopwords.TokenizeText:PR01:Parameters {'**kwargs'} not documented
# pdpipe.nltk_stages.RemoveStopwords.TokenizeText:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.RemoveStopwords.UntokenizeText:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.nltk_stages.RemoveStopwords.UntokenizeText:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.RemoveStopwords.UntokenizeText:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.RemoveStopwords.UntokenizeText:PR01:Parameters {'**kwargs'} not documented
# pdpipe.nltk_stages.RemoveStopwords.UntokenizeText:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.RemoveStopwords.ValDrop:
# A total of 5 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.nltk_stages.RemoveStopwords.ValDrop:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.RemoveStopwords.ValDrop:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.RemoveStopwords.ValDrop:PR01:Parameters {'**kwargs'} not documented
# pdpipe.nltk_stages.RemoveStopwords.ValDrop:PR02:Unknown parameters {'exclude_columns'}
# pdpipe.nltk_stages.RemoveStopwords.ValDrop:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.RemoveStopwords.ValKeep:
# A total of 5 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.nltk_stages.RemoveStopwords.ValKeep:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.RemoveStopwords.ValKeep:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.RemoveStopwords.ValKeep:PR01:Parameters {'**kwargs'} not documented
# pdpipe.nltk_stages.RemoveStopwords.ValKeep:PR02:Unknown parameters {'exclude_columns'}
# pdpipe.nltk_stages.RemoveStopwords.ValKeep:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.RemoveStopwords.apply:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.nltk_stages.RemoveStopwords.apply:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.RemoveStopwords.apply:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.nltk_stages.RemoveStopwords.description:
# A total of 3 errors were found
# Out of which 0 are soft errors, (an additional 3 errors were hidden).
# pdpipe.nltk_stages.RemoveStopwords.description:SS03:Summary does not end with a period
# pdpipe.nltk_stages.RemoveStopwords.description:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.RemoveStopwords.description:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.RemoveStopwords.fit:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.nltk_stages.RemoveStopwords.fit:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.RemoveStopwords.fit:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.nltk_stages.RemoveStopwords.fit_transform:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.nltk_stages.RemoveStopwords.fit_transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.RemoveStopwords.fit_transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.nltk_stages.RemoveStopwords.is_being_fitted_by_pipeline:
# A total of 2 errors were found
# Out of which 0 are soft errors, (an additional 3 errors were hidden).
# pdpipe.nltk_stages.RemoveStopwords.is_being_fitted_by_pipeline:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.RemoveStopwords.is_being_fitted_by_pipeline:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.RemoveStopwords.transform:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.nltk_stages.RemoveStopwords.transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.RemoveStopwords.transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
#
# numpydoc validation results for pdpipe.nltk_stages.SnowballStem:
# A total of 2 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.nltk_stages.SnowballStem:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.SnowballStem:PR01:Parameters {'**kwargs'} not documented
#
# numpydoc validation results for pdpipe.nltk_stages.SnowballStem.AdHocStage:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.nltk_stages.SnowballStem.AdHocStage:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.SnowballStem.AdHocStage:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.SnowballStem.AdHocStage:PR01:Parameters {'**kwargs'} not documented
# pdpipe.nltk_stages.SnowballStem.AdHocStage:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.SnowballStem.AggByCols:
# A total of 6 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.nltk_stages.SnowballStem.AggByCols:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.SnowballStem.AggByCols:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.nltk_stages.SnowballStem.AggByCols:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.SnowballStem.AggByCols:SS06:Summary should fit in a single line
# pdpipe.nltk_stages.SnowballStem.AggByCols:PR01:Parameters {'**kwargs'} not documented
# pdpipe.nltk_stages.SnowballStem.AggByCols:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.SnowballStem.ApplicationContextEnricher:
# A total of 3 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.nltk_stages.SnowballStem.ApplicationContextEnricher:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.SnowballStem.ApplicationContextEnricher:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.SnowballStem.ApplicationContextEnricher:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.SnowballStem.ApplyByCols:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.nltk_stages.SnowballStem.ApplyByCols:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.SnowballStem.ApplyByCols:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.SnowballStem.ApplyByCols:SS06:Summary should fit in a single line
# pdpipe.nltk_stages.SnowballStem.ApplyByCols:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.SnowballStem.ApplyToRows:
# A total of 5 errors were found
# Out of which 1 are soft errors, (an additional 2 errors were hidden).
# pdpipe.nltk_stages.SnowballStem.ApplyToRows:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.SnowballStem.ApplyToRows:GL03:Double line break found; please use only one blank line to separate sections or paragraphs, and do not leave blank lines at the end of docstrings
# pdpipe.nltk_stages.SnowballStem.ApplyToRows:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.SnowballStem.ApplyToRows:PR01:Parameters {'**kwargs'} not documented
# pdpipe.nltk_stages.SnowballStem.ApplyToRows:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.SnowballStem.Bin:
# A total of 4 errors were found
# Out of which 1 are soft errors, (an additional 1 errors were hidden).
# pdpipe.nltk_stages.SnowballStem.Bin:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.nltk_stages.SnowballStem.Bin:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.nltk_stages.SnowballStem.Bin:PR01:Parameters {'**kwargs'} not documented
# pdpipe.nltk_stages.SnowballStem.Bin:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.nltk_stages.SnowballStem.ColByFrameFunc:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [160], in <module>
# ----> 1 validate_module('pdpipe')
#
# Input In [159], in validate_module(module_name)
#      12         module_full_name = f"{module_name}.{name}"
#      13         # print(f"Found pdpipe sub-module {module_full_name}")
# ---> 14         res = recursively_validate_object(obj, module_full_name)
#      15         obj_w_hard_errors.extend(res)
#      16 obj_w_hard_errors = sorted(set(obj_w_hard_errors))
#
# Input In [158], in recursively_validate_object(val_obj, val_full_name)
#       7 if inspect.isclass(obj) or inspect.isfunction(obj):
#       8     full_name = f"{val_full_name}.{name}"
# ----> 9     res = recursively_validate_object(obj, full_name)
#      10     if len(res) > 0:
#      11         obj_w_hard_errors.extend(res)
#
# Input In [158], in recursively_validate_object(val_obj, val_full_name)
#       7 if inspect.isclass(obj) or inspect.isfunction(obj):
#       8     full_name = f"{val_full_name}.{name}"
# ----> 9     res = recursively_validate_object(obj, full_name)
#      10     if len(res) > 0:
#      11         obj_w_hard_errors.extend(res)
#
# Input In [158], in recursively_validate_object(val_obj, val_full_name)
#       1 def recursively_validate_object(val_obj, val_full_name) -> bool:
#       2     obj_w_hard_errors = []
# ----> 3     if get_npdoc_val_report(val_full_name):
#       4         obj_w_hard_errors = [val_full_name]
#       5     for name, obj in inspect.getmembers(val_obj):
#
# Input In [157], in get_npdoc_val_report(object_name)
#      17 print(f"\nnumpydoc validation results for {object_name}:")
#      18 try:
# ---> 19     output = subprocess.check_output(['python', '-m', 'numpydoc', object_name, '--validate'])
#      20 except subprocess.CalledProcessError as e:
#      21     any_errors = True
#
# File ~/.pyenv/versions/3.10.2/lib/python3.10/subprocess.py:420, in check_output(timeout, *popenargs, **kwargs)
#     417         empty = b''
#     418     kwargs['input'] = empty
# --> 420 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     421            **kwargs).stdout
#
# File ~/.pyenv/versions/3.10.2/lib/python3.10/subprocess.py:503, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
# --> 503         stdout, stderr = process.communicate(input, timeout=timeout)
#     504     except TimeoutExpired as exc:
#     505         process.kill()
#
# File ~/.pyenv/versions/3.10.2/lib/python3.10/subprocess.py:1136, in Popen.communicate(self, input, timeout)
#    1134     self._stdin_write(input)
#    1135 elif self.stdout:
# -> 1136     stdout = self.stdout.read()
#    1137     self.stdout.close()
#    1138 elif self.stderr:
#
# KeyboardInterrupt:

# %%
recursively_validate_object(pdpipe.run_time_parameters, 'pdpipe.run_time_parameters')
# Out:
# numpydoc validation results for pdpipe.run_time_parameters:
# No errors found.
#
# numpydoc validation results for pdpipe.run_time_parameters.DynamicParameter:
# No errors found.
#
# numpydoc validation results for pdpipe.run_time_parameters.DynamicParameter.fit_transform:
# A total of 7 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.run_time_parameters.DynamicParameter.fit_transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.run_time_parameters.DynamicParameter.fit_transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.run_time_parameters.DynamicParameter.fit_transform:PR01:Parameters {'y'} not documented
# pdpipe.run_time_parameters.DynamicParameter.fit_transform:PR02:Unknown parameters {'y: optional'}
# pdpipe.run_time_parameters.DynamicParameter.fit_transform:PR09:Parameter "X" description should finish with "."
# pdpipe.run_time_parameters.DynamicParameter.fit_transform:PR10:Parameter "y" requires a space before the colon separating the parameter name and type
# pdpipe.run_time_parameters.DynamicParameter.fit_transform:PR09:Parameter "y: optional" description should finish with "."
#
# numpydoc validation results for pdpipe.run_time_parameters.DynamicParameter.transform:
# A total of 3 errors were found
# Out of which 1 are soft errors, (an additional 3 errors were hidden).
# pdpipe.run_time_parameters.DynamicParameter.transform:GL01:Docstring text (summary) should start in the line immediately after the opening quotes (not in the same line, or leaving a blank line in between)
# pdpipe.run_time_parameters.DynamicParameter.transform:SS05:Summary must start with infinitive verb, not third person (e.g. use "Generate" instead of "Generates")
# pdpipe.run_time_parameters.DynamicParameter.transform:RT01:No Returns section found
#
# numpydoc validation results for pdpipe.run_time_parameters.dynamic:
# A total of 9 errors were found
# Out of which 0 are soft errors, (an additional 3 errors were hidden).
# pdpipe.run_time_parameters.dynamic:SS03:Summary does not end with a period
# pdpipe.run_time_parameters.dynamic:PR01:Parameters {'parameter_selector', 'fittable'} not documented
# pdpipe.run_time_parameters.dynamic:PR02:Unknown parameters {'-------', 'parameter_selector: callable', 'fittable: boolean', 'Returns DynamicParameter'}
# pdpipe.run_time_parameters.dynamic:PR10:Parameter "parameter_selector" requires a space before the colon separating the parameter name and type
# pdpipe.run_time_parameters.dynamic:PR10:Parameter "fittable" requires a space before the colon separating the parameter name and type
# pdpipe.run_time_parameters.dynamic:PR04:Parameter "Returns DynamicParameter" has no type
# pdpipe.run_time_parameters.dynamic:PR04:Parameter "-------" has no type
# pdpipe.run_time_parameters.dynamic:PR07:Parameter "-------" has no description
# pdpipe.run_time_parameters.dynamic:RT01:No Returns section found
# ['pdpipe.run_time_parameters.DynamicParameter.fit_transform',
#  'pdpipe.run_time_parameters.DynamicParameter.transform',
#  'pdpipe.run_time_parameters.dynamic']
